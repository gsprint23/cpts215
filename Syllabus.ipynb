# %% [markdown]
# # [CptS 215](http://piazza.com/wsu/fall2017/cpts215/home) Syllabus - Fall 2017
# Data Analytics Systems and Algorithms
#
# [Washington State University](http://wsu.edu)
#
# ## Instructor Information
# Instructor: [Gina Sprint](http://eecs.wsu.edu/~gsprint/), PhD
#
# Office: Sloan 320
#
# Email: [gsprint@eecs.wsu.edu](mailto:gsprint@eecs.wsu.edu)
#
# Office Hours: TBA, and by appointment
#
# ## Teaching Assistant Information
# TBA

# %% [markdown]
# ## Course Information
# CptS 215 [3 credits]
#
# Data Analytics Systems and Algorithms
#
# ### Prerequisites
# Before taking this course, you need to satisfy the prerequisites listed [here](http://www.catalog.wsu.edu/Pullman/Academics/Courses/CPT_S).
#
# ### Description
# The primary aim of this course is to further expand your understanding of data analytics and algorithms. In this course, we use the Python programming language and libraries to explore the fundamental concepts, constructs, and techniques of modern data analytics systems including: program structures, algorithms, and Big Data sets. Some of these concepts include, but are not limited to, the following:
# * Analyzing and applying data structures -trees, maps, hash tables, etc.
# * Implementing algorithms and data structures in Python
# * Designing and applying systems for data analysis
# * Problem solving with data structures and design techniques
#
# In this course we will emphasize problem solving, algorithmic thinking, and data extraction, filtering, and analysis. Please see the tentative topic schedule listed at the bottom of this page.
#
# The general rule-of-thumb is that you will get as much out of the course as effort that you put into it, so please work diligently and you will be rewarded for the work that you put into the class.
#
#
# ### Learning Objectives
# At the conclusion of this course, you should be able to:
# * Analyze and apply core data structures for data analytics
# * Analyze and apply core algorithms for data analytics
# * Design, implement, and test Python programs applying modern tools and techniques
# * Extract, filter, transform, and computationally analyze data
#
# Additionally, this course targets the WSU and ABET [outcomes](https://abet.eecs.wsu.edu/curricular/CptS) listed [here](https://abet.eecs.wsu.edu/node/417). Please refer to [http://school.eecs.wsu.edu/undergraduate/ABET](http://school.eecs.wsu.edu/undergraduate/ABET) for more information.

# %% [markdown]
# ## Course Materials
#
# ### Course Website
# [http://piazza.com/wsu/fall2017/cpts215/home](http://piazza.com/wsu/fall2017/cpts215/home)
#
# ### Course Files
# [http://nbviewer.jupyter.org/github/gsprint23/cpts215/tree/master/](http://nbviewer.jupyter.org/github/gsprint23/cpts215/tree/master/)

# %% [markdown]
# ### Course Schedule
# |Week|Dates|Unit|Lesson(s)|Reading|Assignment(s)|Assignment(s) Due|
# |:-----|:-----|:-------|:---------|:----------------|:-------------|:------|
# |1|8/21-8/27|Python for Data Analytics|[L1-1](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L1-1.ipynb) Introduction<br>[L1-2](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L1-2.ipynb) OS Commands<br>[L1-3](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L1-3.ipynb) Python Basics|[M&R 1](http://interactivepython.org/runestone/static/pythonds/index.html)|[MA1](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/microassignments/MA1.ipynb)||
# |2|8/28-9/3|Python for Data Analytics|[L2-1](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L2-1.ipynb) Python Basics II<br>[L2-2](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L2-2.ipynb) Built-in Data Structures<br>[L2-3](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L2-3.ipynb) Objects and Classes||[PA1](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/progassignments/PA1.ipynb)||
# |3|9/4-9/10|Python for Data Analytics|[L3-1](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L3-1.ipynb) Jupyter Notebook<br>[L3-2](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L3-2.ipynb) Markdown and Latex<br>[L3-3](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L3-3.ipynb) Plotting|[McKinney 1-3 & 8](https://www.amazon.com/Python-Data-Analysis-Wrangling-IPython/dp/1449319793)|[MA2](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/microassignments/MA2.ipynb)|[MA1](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/microassignments/MA1.ipynb) due |
# |4|9/11-9/17|Python for Data Analytics|[L4-1](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L4-1.ipynb) NumPy and SciPy<br>[L4-2](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L4-2.ipynb) Pandas Series<br>[L4-3](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L4-3.ipynb) Pandas DataFrame|[McKinney 4-6](https://www.amazon.com/Python-Data-Analysis-Wrangling-IPython/dp/1449319793)|[PA2](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/progassignments/PA2.ipynb)|[PA1](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/progassignments/PA1.ipynb) due |
# |5|9/18-9/24|Algorithm Analysis|[L5-1](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L5-1.ipynb) Introduction to Algorithm Analysis<br>[L5-2](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L5-2.ipynb) Analysis of Recursion<br>[L5-3](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L5-3.ipynb) Analysis of Sorting|[M&R 2 & 4](http://interactivepython.org/runestone/static/pythonds/index.html)|[zyBooks 1.1-1.7](https://www.zybooks.com/)<br>[MA3](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/microassignments/MA3.ipynb)|[zyBooks 1.1-1.7](https://www.zybooks.com/) due <br>[MA2](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/microassignments/MA2.ipynb) due |
# |6|9/25-10/1|Algorithm Analysis|[L6-1](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L6-1.ipynb) Merge Sort<br>[L6-2](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L6-2.ipynb) Quick Sort<br>[L6-3](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L6-3.ipynb) <mark>Exam Review</mark>|[M&R 5 (excluding 5.5)](http://interactivepython.org/runestone/static/pythonds/index.html)|[zyBooks 1.7-1.20](https://www.zybooks.com/)<br>[PA3](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/progassignments/PA3.ipynb)|[zyBooks 1.7-1.20](https://www.zybooks.com/) due <br>[PA2](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/progassignments/PA2.ipynb) due |
# |7|10/2-10/8|Algorithm Analysis|[L7-1](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L7-1.ipynb) Lists, Sets, and Linked Lists<br>[L7-2](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L7-2.ipynb) Stacks, Queues, and Deques|[M&R 3](http://interactivepython.org/runestone/static/pythonds/index.html)|[zyBooks 2](https://www.zybooks.com/)<br>[MA4](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/microassignments/MA4.ipynb)|[zyBooks 2](https://www.zybooks.com/) due <br>[MA3](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/microassignments/MA3.ipynb) due <br><mark>Exam #1 due </mark>|
# |8|10/9-10/15|Algorithm Analysis|[L8-1](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L8-1.ipynb) Hashing<br>[L8-2](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L8-2.ipynb) Hash Table Implementation<br>[L8-3](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L8-3.ipynb) Hash Functions|[M&R 5.5](http://interactivepython.org/runestone/static/pythonds/index.html)|[zyBooks 3](https://www.zybooks.com/)<br>[PA4](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/progassignments/PA4.ipynb)|[zyBooks 3](https://www.zybooks.com/) due <br>[PA3](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/progassignments/PA3.ipynb) due |
# |9|10/16-10/22|Trees|[L9-1](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L9-1.ipynb) Trees<br>[L9-2](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L9-2.ipynb) Search Trees<br>[L9-3](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L9-3.ipynb) AVL Trees|[M&R 6.1-6.7 & 6.11-6.22](http://interactivepython.org/runestone/static/pythonds/index.html)|[zyBooks 4.1-4.10](https://www.zybooks.com/)<br>[MA5](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/microassignments/MA5.ipynb)|[zyBooks 4.1-4.10](https://www.zybooks.com/) due <br>[MA4](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/microassignments/MA4.ipynb) due |
# |10|10/23-10/29|Trees|[L10-1](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L10-1.ipynb) Machine Learning<br>[L10-2](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L10-2.ipynb) Decision Trees<br>[L10-3](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L10-3.ipynb) Tree Visualization||[PA5](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/progassignments/PA5.ipynb)|[PA4](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/progassignments/PA4.ipynb) due |
# |11|10/30-11/5|Trees|[L11-1](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L11-1.ipynb) Heaps<br>[L11-2](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L11-2.ipynb) Heap Implementation<br>[L11-3](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L11-3.ipynb) <mark>Exam Review</mark>|[M&R 6.8-6.10](http://interactivepython.org/runestone/static/pythonds/index.html)|[zyBooks 4.11-4.12](https://www.zybooks.com/)<br>[MA6](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/microassignments/MA6.ipynb)<br>[Project](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/project/Project.ipynb)|[zyBooks 4.11-4.12](https://www.zybooks.com/) due <br>[MA5](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/microassignments/MA5.ipynb) due |
# |12|11/6-11/12|Graphs|[L12-1](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L12-1.ipynb) Graphs<br>[L12-2](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L12-2.ipynb) Graph Implementation|[M&R 7.1-7.18](http://interactivepython.org/runestone/static/pythonds/index.html)|[zyBooks 5.1-5.7](https://www.zybooks.com/)<br>[PA6](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/progassignments/PA6.ipynb)|[zyBooks 5.1-5.7](https://www.zybooks.com/) due <br>[PA5](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/progassignments/PA5.ipynb) due <br><mark>Exam #2 due </mark><br>[Project](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/project/Project.ipynb) proposal due |
# |13|11/13-11/19|Graphs|[L13-1](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L13-1.ipynb) Dijkstra's Algorithm<br>[L13-2](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L13-2.ipynb) Minimum Spanning Trees<br>[L13-3](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L13-3.ipynb) Git/Github|[M&R 7.19-7.26](http://interactivepython.org/runestone/static/pythonds/index.html)|[zyBooks 5.8-5.9](https://www.zybooks.com/) due <br>[MA7](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/microassignments/MA7.ipynb)|[zyBooks 5.8-5.9](https://www.zybooks.com/) due <br>[MA6](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/microassignments/MA6.ipynb) due |
# ||11/20-11/26|Break|||||
# |14|11/27-12/3|Data Analytics Systems|[L14-1](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L14-1.ipynb) Case Study: APIs and Graph Mining<br>[L14-2](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L14-2.ipynb) Case Study: Web Scraping<br>[L14-3](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/lessons/L14-3.ipynb) <mark>Final Exam Review</mark>|||[PA6](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/progassignments/PA6.ipynb) due <br>[MA7](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/microassignments/MA7.ipynb) due |
# |15|12/4-12/10|Data Analytics Systems|Project Demos|||[Project](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/project/Project.ipynb) due |
# |16|12/11-12/17|Finals Week||||<mark>Final Exam due </mark>|

# %% [markdown]
# ### Communication
# We will use [Piazza](http://piazza.com/wsu/fall2017/cpts215/home) and [Blackboard](https://learn.wsu.edu/) in this course. I will post important CptS 215 news updates to this site so please check it regularly. Piazza will be used to ask questions and discuss topics with other students in the class, TAs, and the instructor. **Piazza will not be used to share code solutions.** You can however post high level code explanations and/or snippets of pseudocode.
#
# [Blackboard](https://learn.wsu.edu/) will be used to access to course content, submit assignments, and view your grades. I will also email important information to you through Piazza and/or Blackboard. The website URL is: [https://learn.wsu.edu/](https://learn.wsu.edu/) (use your WSU network ID and password to login).
#
# ### Textbooks
# #### Required Textbooks
# ##### zyBooks
# Data Structures Essentials (a [zyBooks](https://zybooks.zyante.com) book). This is an online interactive textbook. Follow these instructions to gain access to the book:
# 1. Sign up at [zybooks.zyante.com](https://zybooks.zyante.com)
# 1. Enter zyBook code WSUCptS215SprintSpring2017
# 1. Click Subscribe
#
# The cost to subscribe is \$48; any applicable returning student discounts will be applied automatically. The student subscriptions will be valid through 05/25/17.
#
# ##### Miller and Ranum
# Miller, Brad and Ranum, David. [*Problem Solving with Algorithms and Data Structures using Python*](https://interactivepython.org/runestone/static/pythonds/index.html) This textbook is freely available online under the Creative Commons license. You can access the html version [here](https://interactivepython.org/runestone/static/pythonds/index.html).
#
# #### Supplementary Textbooks
# McKinney, Wes. [*Python for Data Analysis: Data Wrangling with Pandas, NumPy, and Python*](https://www.amazon.com/Python-Data-Analysis-Wrangling-IPython/dp/1491957662/ref=sr_1_2?ie=UTF8&qid=1481234925&sr=8-2&keywords=python+for+data+analysis), O'Reilly Media, Inc., 2017. ISBN: 978-1449319793
#
# Downey, Allen. [*How to Think Like a Computer Scientist (2nd edition)*](http://interactivepython.org/courselib/static/thinkcspy/index.html/). This textbook is freely available online under the Creative Commons license. You can access the html version [here](http://interactivepython.org/courselib/static/thinkcspy/index.html).
#
# Also, there are several other Python books and resources listed on the [course website](http://piazza.com/wsu/fall2017/cpts215/home) under Resources. Also, check out this page that has a list of several free and for sale Python books: [http://importpython.com/books/](http://importpython.com/books/). There are alot of great resources to help you learn Python, data structures, and algorithms.
#
# ### Required Hardware
# A laptop adhering to EECS requirements. Please refer to [https://school.eecs.wsu.edu/?s=laptop](https://school.eecs.wsu.edu/?s=laptop).
#
# ### Required Software
# [Anaconda3](https://docs.continuum.io/anaconda/index) Python3 distribution. This is a free distribution of Python version 3 available for Windows, OS X, and Linux. You can download Anaconda3 [here](https://www.continuum.io/downloads) and view the installation instructions [here](https://docs.continuum.io/anaconda/install).

# %% [markdown]
# ## Course Grading
# ### Programming Assignments
# You will be given 6 programming assignments to complete. All Python code written in assignments must adhere to the recommended [Python Style and Coding Standards](http://nbviewer.jupyter.org/github/gsprint23/cpts215/blob/master/CptS215CodingStandard.ipynb); your TA will let you know if you are not adhering to these standards. **Programming assignments should be completed independently**. It is easy to detect code sharing, don't do it.
#
# Please upload assignments as attached .zip files to the corresponding assignment in Blackboard. Recall the site is https://learn.wsu.edu/. Please refer to the course schedule in for assignments and dates. All programming assignments must be submitted by midnight of the due date.
#
# ### Micro Assignments
# Micro assignments ensure that the material is understood and you are staying on top of the textbook reading assignments. Micro assignments may be written problems graded for correctness and/or participation, small programming assignments, or writing assignments.
#
# Please upload assignments as attached .zip files to the corresponding assignment in Blackboard. Recall the site is https://learn.wsu.edu/. Please refer to the course schedule in for assignments and dates. All micro assignments must be submitted by midnight of the due date.
#
# ### Project
# The final project in the class will have students implement a data analytics system in Python. The system will be proposed by students in groups of two.
#
#
# ### zyBooks Textbook Reading
# You will be graded for completing participation and challenge activities in the zyBooks textbook.
#
# ### Exams
# We will have two midterm exams and one final exam in this course. Please see the course schedule for the dates of the exams.
#
# ### Participation
# You are expected to participate regularly in Piazza discussions and attend the instructor/TAs virtual office hours.
#
# ### Assignment Weights
# * Programming assignments (25%)
# * Micro assignments (20%)
# * Project (10%)
# * zyBooks textbook activities (10%)
# * Two midterm exams (20%, 10% each)
# * One final exam (15%)
#
# #### Grading Scale
# |Percentage|Grade|
# |:----------|:-----|
# |94-100%   |A|
# |90-93.99% |A-|
# |86-89.99% |B+|
# |82-85.99% |B|
# |78-81.99% |B-|
# |74-77.99% |C+|
# |70-73.99% |C|
# |66-69.99% |C-|
# |62-65.99% |D+|
# |58-61.99% |D|
# |0-57.99%  |F|
#
# #### Contesting a Grade
# If you believe that a mistake has been made with grading an assignment or exam, please speak with the instructor or TA within one week of the assignment or exam being returned. Do not wait until the end of the semester to discuss any grade changes. You need to constantly be aware of how you are performing in the class. Thus, there will not be any surprises at the end of the semester when grades are to be formally submitted. You should be able to view your grades via Blackboard. These will be updated weekly.
#
# Note: the grades in Blackboard may just be raw scores and not be weighted according to the ones described here. Thus, be sure that you keep track of these weights so that you are not surprised by a change in your overall grade at the end of the semester.
#
# ## Course Policies
# ### Late Work Policy
# Assignments are due by the established due dates and times stated in the course schedule on Blackboard. You may submit an assignment up to two days late (the weekend counts as one day), at a penalty of 10% per 24 hours late. Forty-eight hours after the assignment is due, you may no submit the assignment for credit. If an emergency occurs, the instructor will accommodate the student as much as possible. Make-up exams will not be possible unless the student speaks with the instructor at least two days in advance. Emergencies do occur and rescheduling of exams because of these is to be determined by the instructor.
#
# ### EECS Computing Policies
# You may read about EECS's school computing policies at the following site [https://school.eecs.wsu.edu/documents/2016/08/eecs-computing-policies.pdf](https://school.eecs.wsu.edu/documents/2016/08/eecs-computing-policies.pdf).
#
# ### Academic Integrity Policy
# #### University Policy
# Academic integrity is the cornerstone of higher education. As such, all members of the university community share responsibility for maintaining and promoting the principles of integrity in all activities, including academic integrity and honest scholarship. Academic integrity will be strongly enforced in this course. Students who violate WSU's Academic Integrity Policy (identified in Washington Administrative Code (WAC) 504-26-010(3) and -404) will fail the course, will not have the option to withdraw from the course pending an appeal, and will be reported to the Office of Student Conduct. Cheating includes, but is not limited to, plagiarism and unauthorized collaboration as defined in the Standards of Conduct for Students, WAC 504-26-010(3). You need to read and understand all of the definitions of cheating: [http://app.leg.wa.gov/WAC/default.aspx?cite=504-26-010](http://app.leg.wa.gov/WAC/default.aspx?cite=504-26-010).
#
# You are expected to know and understand Washington State University Academic Integrity Policies. Copying and plagiarism of other sources will result in an automatic F on the assignment. For a second offense, an automatic F in the course will be awarded without the option to withdraw. University authorities will be notified and the proper procedures will be followed. Possible outcomes resulting from violating these policies include denial of certification into your program and expulsion.
#
# If you have any questions about what is and is not allowed in this course, you should ask course instructors before proceeding. If you wish to appeal a faculty member's decision relating to academic integrity, please use the form available at [conduct.wsu.edu](http://conduct.wsu.edu).
#
# Please also review the following website for more information about the EECS academic integrity policy (if any discrepancies are found within the EECS and WSU academic integrity policies, always follow the WSU policy): [http://www.eecs.wsu.edu/~schneidj/Misc/academic-integrity.html](http://www.eecs.wsu.edu/~schneidj/Misc/academic-integrity.html)
#
# #### CptS 215 Policy
# For this course both group and individual work will be required. Group work includes:
# 1. zyBooks activities
# 1. Some MAs
# 1. Project
#
# Individual work includes:
# 1. PAs
# 1. Exams/quizzes
# 1. Some MAs
#
# All individual work must be completed alone. **Do NOT work with any team members on individual assignments.** You may discuss ideas with team members about problems related to individual assignments, but do not discuss implementation details. Discussing implementation details includes (but is not limited to):
# 1. Copying/taking a picture of another student's code/work
# 1. Letting another student copy/take a picture of your code/work
# 1. Sending your code/work to another student (i.e. digitally or in print)
# 1. Receiving another's student code/work (i.e. digitally or in print)
#
# Note: If you use content from sources other than the ones provided by the instructor (e.g. textbook, notes, etc.), cite the source in your code.
#
# Here are few example scenarios (adapted from Aaron Crandall's CptS 223 Syllabus):
# 1. You and a few friends are working together on an individual assignment. You just finished the assignment but have to head to class. One of your friends asks you for a copy of your work so that he/she can use it as a guide. Wanting to be a good friend, you email him/her a copy of your assignment on the promise that he/she won't copy.
#     * Is this cheating? YES! You are violating implementation detail #3 (above) and your friend is violating implementation detail #4.
# 1. You and a few friends are working together on an individual assignment. You just finished the assignment but have to head to class. One of your friends asks to meet up with you later for some help. You meet up with him/her after class and answer his/her questions with high-level descriptions on a white board (e.g. "here is an example of how a for loop works") and pictures (e.g. a drawing).
#     * Is this cheating? No, this kind of working together is encouraged.
# 1. Your friend is almost done with his individual assignment but is stuck debugging. You take a look at his/her program and quickly realize that his/her loop is off by one. You explain how to fix the error to your friend.
#     * Is this cheating? No, this kind of working together is encouraged.
# 1. On Piazza, a student has asked for code help on an individual assignment. You respond with a short code snippet.
#     * Is this cheating? No, this kind of working together is encouraged.
# 1. You are stuck on an individual assignment, say coding a Hangman game, and turn to Google to help you out. You find code that completely implements the game of Hangman! You download the code, modify it to meet the assignment requirements, and turn it in.
#     * Is this cheating? YES! This is plagiarism.
#
# If are unsure of whether a situation might be considered cheating, be cautious and don't do it. If help is required please ask the instructor or TA for guidance. We are always more than willing to help!!
#
# ### Classroom Safety Statement
# Classroom and campus safety are of paramount importance at Washington State University, and are the shared responsibility of the entire campus population. WSU urges students to follow the "Alert, Assess, Act," protocol for all types of emergencies and the ["Run, Hide, Fight" response](https://oem.wsu.edu/emergency-procedures/active-shooter/) for an active shooter incident. Remain ALERT (through direct observation or emergency notification), ASSESS your specific situation, and ACT in the most appropriate way to assure your own safety (and the safety of others if you are able).
#
# Please sign up for emergency alerts on your account at MyWSU. For more information on this subject, campus safety, and relate topics, please view the [FBI's Run, Hide, Fight video](https://oem.wsu.edu/emergency-procedures/active-shooter/) and visit the [WSU safety portal](https://oem.wsu.edu/about-us/).
#
#
# ### WSU's AWARE Network
# As a student you have many responsibilities and obligations. One of the most important obligations that you may have is to your friends and peers at WSU. If you feel like one of your friends or peers is struggling with academics because of physical or mental health please inform me and/or appropriate university personnel. For more information refer to [http://aware.wsu.edu/](http://aware.wsu.edu/)
#
# ### Documented Disabilities
# Washington State University has facilities and resources available for accommodating students with disabilities. Please notify the instructor during the first week of class of any accommodations needed for the course.
#
# ### Pullman Campus Syllabus Statement
# Students with Disabilities: Reasonable accommodations are available for students with a documented disability. If you have a disability and need accommodations to fully participate in class, please either visit or call the [Access Center](http://accesscenter.wsu.edu) (Washington Building 217; 509-335-3417) to schedule an appointment with an Access Advisor. All accommodations MUST be approved through the Access Center.  You may also contact the Access Center via email: [Access.Center@wsu.edu](mailto:access.center@wsu.edu).

# %% [markdown]
# ## Final Notes
# ### Free Tutoring
# The Voiland College of Engineering and Architecture offers free tutoring for students in CptS 215. For more information and the tutor schedule, see [https://vcea.wsu.edu/tutors/](https://vcea.wsu.edu/tutors/).
#
# ### Advice
# The fastest (and easiest) way to get better at programming is to program! This course moves fast and if you don't stay on top of the assignments and reading it will be difficult to catch up. You will do great in the course if you put the time in to learn the material on schedule and practice programming data structures :)

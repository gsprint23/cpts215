# %% [markdown]
# # [CptS 215 Data Analytics Systems and Algorithms](https://piazza.com/wsu/spring2017/cpts215/home)
# [Washington State University](https://wsu.edu)
#
# [Gina Sprint](http://eecs.wsu.edu/~gsprint/)
# # L6-3 Exam #1 Review
#
# Learner objectives for this lesson:
# * Review material for exam #1
#
#
# ## Acknowledgments
# Content used in this lesson is based upon information in the following sources:
# * No sources to report

# %% [markdown]
# ## What can be Used?
# * Two sharp pencils
# * Python Programming knowledge in your head :)
#
# ## What CANNOT be Used?
# * Electronics (including calculators) may not be used during the exam!
# * Notes may not be used during the exam!
#
# Note: If you are caught cheating, your exam will be confiscated and you will receive a 0.
#
# Note: Use the restroom before class. **Once testing starts, the only reason for leaving the exam is turning in your exam as done.**
#
# ## Exam Timeframe
# Please be aware that, because you will be taking the exam during a normal lecture period (50 minutes), time will be extremely tight for the exam so manage your time well. If you show up late to class, you will have less time to take the exam.

# %% [markdown]
# ## Exam Coverage
# The exam covers everything we have covered so far in the course. Here is an outline of the topics we have covered so far:
#
# ### 0 Introductory Material
# * What is data analytics?
# * What is data analytics systems and algorithms?
# * What is an algorithm?
# * What are Unix-based machines? Provide a few examples
# * File systems and paths
#     * Relative vs absolute paths
# * Command line
#     * Windows (command prompt)
#     * Unix-based (terminal)
# * Operating systems commands
#     * Regardless of whether you use a Windows or a Unix-based machine, you should be comfortable with commands for either OS
#     * Note: see the lesson notes for all OS commands
#     * Getting help on commands
#     * Navigating file systems
#     * What is the current working directory?
#         * Describe why the cwd is important
#     * Creating/removing/copying/moving/modifying files/folders
#     * File permissions
#     * File and string searching
#     * Environment variables
#         * What is the path variable and why is it important?
#     * IP/MAC addresses
# * Python modes: interactive vs. scripting
# * Running Python from the command line
#
#
# ### 1 Python Basics
# (Chapter 1 in [Miller and Ranum](http://interactivepython.org/runestone/static/pythonds/index.html))
# * Spectrum of high level programming languages
# * Python language elements
# * Modules
# * Functions
# * Conditionals
# * Loops
#     * `for` vs `while` loops
#     * `range()`
# * Random number generation using the `random` module
# * File I/O
# * Working with strings
#     * Are strings mutable?
# * Working with lists
#     * Are lists mutable?
# * Working with tuples
#     * Are tuples mutable?
# * Working with dictionaries
#     * Are dictionaries mutable?
# * Object aliasing
# * Command line arguments
# * Object oriented programming (OOP)
#     * Defining classes
#     * Instantiating objects
#     * Functions vs. methods
#     * What are special methods? Explain and implement the ones covered in class
#     * Operator overloading
#     * Polymorphism
#     * Composition
#     * Inheritance
#         * What is `super()` and how do you use it?
#
# ### 2 Python for Data Analytics
# (Chapters 1-6, 8 in McKinney)
# * Jupyter Notebook
#     * Code cells
#     * Markdown cells
#         * Markdown syntax
#         * Latex syntax
#     * Notebook work flow
#     * Data science story-telling with notebooks
# * Plotting with `matplotlib`
#     * Different ways to use `matplotlib`
#         * `pyplot` vs. hybrid `pyplot`/OOP vs. OOP
#     * Parts of a figure
#     * Different types of plots
#         * Line
#         * Bar
#         * Histogram
#         * Scatter
#     * Adding a legend
#     * Customizing plots
# * Numpy and Scipy
#     * What is the `ndarray` class? Why is it great for data analytics?
#         * `ndarray` functions and methods
#         * What are the differences between Python lists and `ndarray`s?
#             * Example: How is slicing different? Copy vs. view
#     * Vectorization and broadcasting
#     * Random number generation with `numpy`
# * Pandas `Series`
# * Pandas `DataFrame`
# * What is k-means clustering?
#     * How to implement k-means clustering using Python data science libraries
#
# ### 3 Algorithm Analysis
# (Chapter 1 in zyBooks; Chapters 2, 4, and 5 in [Miller and Ranum](http://interactivepython.org/runestone/static/pythonds/index.html))
# * What is algorithm analysis? Why analyze algorithms for efficiency?
# * Time vs. space complexity
# * Big O notation
#     * Best case
#     * Worst case
#     * Average case
# * Operation counting and growth rate functions
# * Common time complexities
#     * Constant, logarithmic, linear, log linear, quadratic, cubic, polynomial, exponential
# * Analysis of recursion
# * Analysis and implementation of sorting routines
#     * With particular emphasis on shell sort, merge sort, and quick sort
# * Time complexities of common algorithms

# %% [markdown]
# ## Recommended Studying Strategy
# The exam questions will require you to solve problems in a variety of formats: defining key terms, evaluating expressions, writing code, determining the output of code, etc.
#
# I recommend that you use the following activities and materials to prepare for the exam:
# * Review micro assignments, programming assignments, and problems solved in class
#     * These may well be your best resources. An excellent learning activity would be to re-solve the micro assignments, programming assignments, and in class exercises.
# * Lesson notes and example code
# * Read or re-read the related chapters in zyBooks and the textbooks

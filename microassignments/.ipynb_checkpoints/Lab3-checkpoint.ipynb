# %% [markdown]
# # [CptS 111 Introduction to Algorithmic Problem Solving](http://piazza.com/wsu/fall2016/cpts111/home)
# [Washington State University](https://wsu.edu)
#
# [Gina Sprint](http://eecs.wsu.edu/~gsprint/)
# ## Lab3 Functions (10 pts)
#
# ### Learner Objectives
# At the conclusion of this lab, participants should be able to:
# * Call standard Python functions
# * Define functions
# * Call programmer-defined functions
# * Pass arguments into functions
# * Return values from functions
#
# ### Prerequisites
# Before starting this lab, participants should be able to:
# * Apply basic arithmetic operations in Python
# * Read input from the user
# * Convert strings to numeric types
# * Perform modulo arithmetic
#
# ### Lab Format
# #### Task 0 and Pair Task
# Task 0 will be completed as a group with step-by-step guidance from your TA. After Task 0, your TA will group you into pairs and assign you a task (one of Tasks 1-10).
#
# #### Additional Tasks
# Once you complete Task 0 and your assigned task with a partner (pair task), you are to continue solving additional lab tasks until the end of lab. You are encouraged to complete *all* of the lab tasks. Practice, practice, practice!
#
# #### Completing a Task
# When you complete a task, show your TA your code and output. Also, help others with this task either in person or by answering questions in your [Piazza](http://piazza.com/wsu/fall2016/cpts111/home) lab section group. Helping your peers benefits both you and your classmates, as Albert Einstein said, "You do not really understand something unless you can explain it to your grandmother." :)
#
# #### Lab Dismissal
# You are dismissed from lab when your TA dismisses you, or after 3 hours, whichever comes first. Your TA will dismiss you once you have demonstrated mastery of the material (completed a certain number of tasks). Should you demonstrate mastery before the end of lab, you are encouraged to stay and perform a combination of the following:
# * Help your peers
# * Work on additional tasks
# * Work on the current programming assignment
#
# Take advantage of your TA and your peers as resources and make the most of lab time!
#
# #### Note: Review Labs
# Labs 6 and 11 will be "review" labs where you solve/demo tasks you have not previously solved:
# 1. Lab 6 (week 7): A certain number of tasks from Labs 1-6.
# 1. Lab 11 (week 12): A certain number of tasks from Labs 7-11.
#
# Logically, it is to your benefit to work on the additional tasks now with the help of your TA and peers (and it will save you time later!).

# %% [markdown]
# ## Task 0
# For this task, we are going to re-write our code from Lab1 Task0 to make use of functions. Write a program to compute the BMI (body mass index) for a person given their weight (in pounds) and height (in inches). The BMI formula is as follows:
# $$BMI = \frac{weight}{height^{2}} \times 703$$
#
# Define *at least* the following functions in your solution:
# 1. `get_user_weight()`: Prompts the user to enter their weight in pounds and returns the weight.
# 1. `get_user_height()`: Prompts the user to enter their height in *feet and inches*. Convert the feet and inches to total inches and return this value.
# 1. `compute_BMI()`: Accepts two arguments, `weight_pounds` and `height_inches` and returns the resulting BMI.
# 1. `display_BMI()`: Accepts three arguments, `weight_pounds`, `height_inches`, and `bmi` and displays the results.
#
# Check your computation is correct by comparing it to an [online BMI calculator](http://www.bmi-calculator.net/).
#
# Example output:
#
# ```
# Please enter the weight in pounds: 150
# Please enter the height in feet: 5
# Please enter the remaining height in inches: 0
# The BMI for a person with weight 150.00 pounds and height 60.00 inches is: 29.29
# ```

# %% [markdown]
# ## Task 1
# Write a program to display the sum of the digits of a number. Prompt the user to enter this number, a *positive integer up to five digits long* (i.e., between 0 and 99999).
#
# Define *at least* the following functions in your solution:
# 1. `get_num()`: Prompts the user to enter a positive integer up to five digits long and returns the number.
# 1. `sum_digits()`: Accepts a single argument, `num`, and returns the sum of the digits in `num`.
# 1. `display_sum_digits()`: Accepts two arguments, `num` and `summation`, and displays the results.
#
# For example, for 5378 the sum is 5 + 3 + 7 + 8 = 23.
#
# Example output:
#
# ```
# Please enter a positive integer up to five digits long (i.e. between 0 and 99999): 12345
# The sum of the digits in 12345 is 15.
# ```

# %% [markdown]
# ## Task 2
# This task is adapted from chapter 2 (problem 10) Hanly & Koffman. The problem states the following:
#
# Write a program that outputs the equation of the perpendicular bisector of the line segment between two points.
# ![](https://raw.githubusercontent.com/gsprint23/cpts111/master/labs/figures/perp_bisector.png)
#
# Define *at least* the following functions in your solution:
# 1. `get_coordinate()`: Accepts a single argument that is a string storing "x" or "y". Prompts the user for a x or y coordinate and returns the coordinate. Call this function 4 times to get (x, y) coordinates of the two points.
# 1. `compute_slope()`: Accepts 4 arguments, the 4 coordinates of the two points entered by the user. Computes the slope of the line between those two points and returns the slope.
# 1. `compute_average()`: Accepts 2 arguments, `num1` and `num2`, and returns the average of these two numbers. Call this function twice to compute the coordinates of the midpoint ($x_{mid}$, $y_{mid}$) of the line segment between the two points by averaging the two x coordinates and the two y coordinates.
# 1. `compute_perpendicular_slope()`: Accepts a single argument, `slope`. Computes the slope of the perpendicular bisector ($m_{perp}$) by taking the negative reciprocal of the slope of the line segment and returns this value.
# 1. `compute_y_intercept()`: Accepts 3 arguments, `x`, `y`, and `slope`. Computes the y intercept ($b_{perp}$) of the perpendicular bisector (you now have the slope $m_{perp}$ of the bisector and a point ($x_{mid}$, $y_{mid}$) on the bisector, so $b_{perp} = y_{mid} – m_{perp} * x_{mid}$). Returns the y intercept $b_{perp}$.
# 1. `display_line_equation()`: Accepts 6 arguments, the original 4 coordinates of the two points entered by the user, $m_{perp}$ and $b_{perp}$. Outputs the labels of the original two points and outputs in $y = mx + b$ format the equation of the perpendicular bisector.
#
# Test your program on different pairs of points. You can check your work with [this online calculator](http://www.meracalculator.com/graphic/perpendicularbisector.php). Of course, there exist some pairs of points that will make your program not work. You do not have to check programmatically for these points; just consider them.
#
# Be sure to use the guidance of your TA to determine appropriate functions for this problem!

# %% [markdown]
# ## Task 3
# Write a program that calculates the Bowl Championship Series (BCS) score of a college football team. A college team's BCS ranking comprises 3 elements. These include results from the Harris Poll, the Coaches Poll, and computer rankings. Each one of these is 1/3 the final ranking.
#
# * A team's score in the Harris poll is divided by 2,850, which is the maximum number of points any team can receive if all 114 voting members rank the same team as number 1. Prompt the user for a team's score in the Harris Poll (a number between 1 and 2,850)
# * A team's score in the Coaches poll is divided by 1,475, which is the maximum number of points any team can receive if all 59 voting members rank that same team number 1. Prompt the user for a team's score in the Coaches Poll (a number between 1 and 1,475).
# * The computer rankings is calculated by magical formula that we are not concerned with. However, we know that this value is between 0 and 1. Call this value `computer_ranking`. Prompt the user for the computer ranking.
#
# Once you have the entire set of input values, divide the Harris Poll score by 2,850 (call the result `harris_poll`) and the Coaches Poll score by 1,475 (call the result `coaches_poll`) and print out the intermediate results. The BCS total score may be determined by the following formula:
#
# `BCS_score = (harris_poll + coaches_poll + computer_ranking) / 3`
#
# Display the BCS total score. The number should be between 0 and 1. 1 would indicate a perfect score.
#
# Define and call functions that perform the following:
# 1. Computes the BCS score
# 1. Displays the results
#
# Use additional functions where appropriate!

# %% [markdown]
# ## Task 4
# This task is adapted from chapter 3 (problem 1) Hanly & Koffman and based on PA1. The problem states the following:
#
# You have saved some money to use as a down payment on a car. Before beginning your car shopping, you decide to write a program to help you figure out what your monthly payment will be, given the car's purchase price, the monthly interest rate, and the time period over which you will pay back the loan.
#
# For calculating monthly payments, use the following formula:
#
# $$mpymt = \frac{r(P)}{1 - (1 + r)^{-n}}$$
#
# Where $r$ is the *monthly* interest rate, $P$ is the cost of the car, and $n$ is the number of monthly payments. You can figure out $r$ by converting the interest rate the user enters to a decimal (divide by 100) and then dividing by 12 (12 months in a year).
#
# Your program should prompt the user for the purchase price, the down payment, the annual interest rate and the total number of payments (usually 36, 48, or 60). It should then display the amount borrowed and the monthly payment including a dollar sign and two decimal places.
#
# Define and call functions that perform the following:
# 1. Computes the monthly payment
# 1. Displays the results
#
# Use additional functions where appropriate!

# %% [markdown]
# ## Task 5
# This task is adapted from chapter 3 (problem 6) Hanly & Koffman. The problem states the following:
#
# Four track stars have entered the mile race at the Penn Relays. Write a program that reads in from the user the race time in minutes and seconds for each runner and computes and displays the speed in feet per second (fps) and in meters per second (mps). (Hints: There are 5,280 feet in one mile, and one kilometer equals 3,282 feet.)
#
# |Minutes|Seconds|
# |-|-|
# |3|52.83|
# |3|59.83|
# |4|00.03|
# |4|16.22|
#
# You can check your speed conversions [here](http://www.calculatorsoup.com/calculators/conversions/speed.php).
#
# Define and call functions that perform the following:
# 1. Displays instructions to the user
# 1. Computes the race time in terms of total seconds
# 1. Computes the fps
# 1. Computes the mps
# 1. Displays the results
# 1. Processes a single runners race time by calling the above 4 functions. Ask your TA for help with this!
#
# Use additional functions where appropriate!
#
# Example output:
#
# ```
# This program computes the speed for a runner in feet per second and meters per second.
# You will be prompted to enter the duration in minutes and second for 4 runners who completed the mile race.
#
# Please enter the number of minutes: 3
# Please enter the number of seconds: 52.83
# This runner ran 22.68 feet/sec (6.91 meters/sec)
#
# Please enter the number of minutes: 3
# Please enter the number of seconds: 59.83
# This runner ran 22.02 feet/sec (6.71 meters/sec)
#
# Please enter the number of minutes: 4
# Please enter the number of seconds: 0.03
# This runner ran 22.00 feet/sec (6.70 meters/sec)
#
# Please enter the number of minutes: 4
# Please enter the number of seconds: 16.22
# This runner ran 20.61 feet/sec (6.28 meters/sec)
#
# ```

# %% [markdown]
# ## Task 6
# This task is adapted from chapter 3 (problem 8) Hanly & Koffman. The problem states the following:
#
# A cyclist coasting on a level road slows from a speed of 10 mi/hr to 2.5 mi/hr in one minute. Write a computer program that calculates the cyclist's constant rate of acceleration and determines how long the cyclist will take to come to rest, given an initial speed of 10 mi/hr. Hint: Use the equation:
# $$a = \frac{v_f-v_i}{t}$$
# Where $a$ is acceleration, $v_i$ is initial velocity, and $v_f$ is final velocity.
#
# Define and call functions that perform the following:
# 1. Displays instructions to the user
# 1. Computes the acceleration
# 1. Computes the time to resting
# 1. Displays the results
#
# Use additional functions where appropriate!
#
# Example output:
#
# ```
# This program computes a cyclist's constant rate of acceleration and how long it takes for the cyclist to coast to a stop.
# Please enter the initial velocity: 10.0
# Please enter the final velocity: 2.5
# Constant acceleration: -7.50 miles / hour / min
# Time until stopped: 1.33 mins
# ```

# %% [markdown]
# ## Task 7
# This task is adapted from chapter 3 (problem 9) Hanly & Koffman. The problem states the following:
#
# A manufacturer wishes to determine the cost of producing an open-top cylindrical container. The surface area of the container is the sum of the area of the circular base plus the area of the outside (the circumference of the base times the height of the container). Write a program to take the radius of the base, the height of the container, the cost per square centimeter of the material (cost), and the number of containers to be produced (quantity). Calculate the cost of each container and the total cost of producing all the containers.
#
# Define and call functions that perform the following:
# 1. Displays instructions to the user
# 1. Computes surface area
# 1. Computes the cost of a single cylinder
# 1. Computes the total cost of all the cylinders
# 1. Displays the results
#
# Use additional functions where appropriate!
#
# Example output:
#
# ```
# Please enter the radius of the base [cm]: 3.5
# Please enter the height of the base [cm]: 11.25
# Please enter the cost per cm of the material [$]: 0.04
# Please enter the number of containers to produce [quantity]: 120
# A single container costs $11.44 to produce.
# Producing 120 containers costs $1372.25.
# ```

# %% [markdown]
# ## Task 8
# This task is adapted from chapter 3 (problem 10) Hanly & Koffman. The problem states the following:
#
# Write a program to take a depth (in kilometers) inside the earth as input data; compute and display the temperature at this depth in degrees Celsius and degrees Fahrenheit. The relevant formulas are:
#
# $$celsius = 10 \times depth + 20$$
#
# $$fahrenheit = 1.8 \times celsius + 32$$
#
# for Celsius temperature at depth in km.
#
# Define and call functions that perform the following:
# 1. Gets the depth in km from the user
# 1. Computes and return the Celsius temperature at a depth measured in km
# 1. Converts a Celsius temperature to Fahrenheit
# 1. Displays the results
#
# Use additional functions where appropriate!

# %% [markdown]
# ## Task 9
# This task is adapted from chapter 3 (problem 12) Hanly & Koffman. The problem states the following:
#
# Write a program that calculates the speed of sound ($a$) in air of a given temperature $T$ (°F). Formula to compute the speed in ft/sec:
#
# $$a = 1086\sqrt{\frac{5T+297}{247}}$$
#
# Define and call functions that perform the following:
# 1. Displays instructions to the user
# 1. Gets the air temperature from the user
# 1. Computes the speed of sound
# 1. Displays the results
#
# Use additional functions where appropriate!

# %% [markdown]
# ## Task 10
# Write a program that reads in a positive number with a fractional part from the user and rounds it to the nearest integer. For example, 32.4851 would round to 32, and 32.5101 would round to 33. Write a function called `round_nearest_integer()` that implements your solution (you may not use the built-in Python `round()` function to do this). Hint: think of the integer type.
#
# Challenge: Write another function called `round_two_decimals()` that takes a positive number with a fractional part and rounds it to two decimal places. For example, 32.4851 would round to 32.49, and 32.4431 would round to 32.44.
#
# Define and call functions that perform the following:
# 1. Gets the floating point number from the user
# 1. Computes the integer round
# 1. Computes the 2-decimal place round
# 1. Displays the results
#
# Use additional functions where appropriate!

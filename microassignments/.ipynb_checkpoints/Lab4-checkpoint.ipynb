# %% [markdown]
# # [CptS 111 Introduction to Algorithmic Problem Solving](http://piazza.com/wsu/fall2016/cpts111/home)
# [Washington State University](https://wsu.edu)
#
# [Gina Sprint](http://eecs.wsu.edu/~gsprint/)
# ## Lab4 Functions and Turtle Graphics (10 pts)
#
# ### Learner Objectives
# At the conclusion of this lab, participants should be able to:
# * Use Turtle graphics
# * Define and call functions that execute Turtle graphics code
#
# ### Prerequisites
# Before starting this lab, participants should be able to:
# * Call standard Python functions
# * Define functions
# * Call programmer-defined functions
# * Pass arguments into functions
# * Return values from functions
#
# ### Lab Format
# #### Task 0 and Pair Task
# Task 0 will be completed as a group with step-by-step guidance from your TA. After Task 0, your TA will group you into pairs and assign you a task (one of Tasks 1-10).
#
# #### Additional Tasks
# Once you complete Task 0 and your assigned task with a partner (pair task), you are to continue solving additional lab tasks until the end of lab. You are encouraged to complete *all* of the lab tasks. Practice, practice, practice!
#
# #### Completing a Task
# When you complete a task, show your TA your code and output. Also, help others with this task either in person or by answering questions in your [Piazza](http://piazza.com/wsu/fall2016/cpts111/home) lab section group. Helping your peers benefits both you and your classmates, as Albert Einstein said, "You do not really understand something unless you can explain it to your grandmother." :)
#
# #### Lab Dismissal
# You are dismissed from lab when your TA dismisses you, or after 3 hours, whichever comes first. Your TA will dismiss you once you have demonstrated mastery of the material (completed a certain number of tasks). Should you demonstrate mastery before the end of lab, you are encouraged to stay and perform a combination of the following:
# * Help your peers
# * Work on additional tasks
# * Work on the current programming assignment
#
# Take advantage of your TA and your peers as resources and make the most of lab time!
#
# #### Note: Review Labs
# Labs 6 and 11 will be "review" labs where you solve/demo tasks you have not previously solved:
# 1. Lab 6 (week 7): A certain number of tasks from Labs 1-6.
# 1. Lab 11 (week 12): A certain number of tasks from Labs 7-11.
#
# Logically, it is to your benefit to work on the additional tasks now with the help of your TA and peers (and it will save you time later!).

# %% [markdown]
# ## Task 0
# For this task (and other tasks in this lab), we are going to use the [Turtle graphics](https://docs.python.org/3.4/library/turtle.html) module. Imagine a turtle standing at the origin (0,0) of an x-y canvas. For fun, let's name this turtle Crush (from Finding Nemo):
# <img src="https://raw.githubusercontent.com/gsprint23/cpts111/master/labs/figures/crush_turtle.png" width="500"/>
# Crush is carrying a pen in his mouth. When we give Crush commands like `forward(15)` or `right(15)`, we can move Crush around, thus drawing a picture. Take a moment and read through the list of available turtle commands [here](https://docs.python.org/3.4/library/turtle.html#overview-of-available-turtle-and-screen-methods).
#
# Here are some common turtle methods (methods are functions that are associated with an object):
# 1. `forward(<number of pixels)`: moves the turtle forward a specified number of pixels
# 1. `backward(<number of pixels)`: moves the turtle backward a specified number of pixels
# 1. `left(<number of degrees>)`: rotates the turtle counter clockwise a specified number of degrees
# 1. `right(<number of degrees>)`: rotates the turtle clockwise a specified number of degrees
# 1. `setpos(<x coordinate>, <y coordinate>)`: moves the turtle to the x, y coordinate arguments
# 1. `speed(<integer speed>)`: increase the animation speed. An argument of 0 indicates the fastest drawing speed. See other speed options[here](https://docs.python.org/3.4/library/turtle.html#turtle.speed)
# 1. `penup()`: lifts the pen up so the turtle does not draw on the canvas when he/she moves
# 1. `pendown()`: lowers the pen to the canvas so the turtle does draw when he/she moves
# 1. `pencolor(<color string>)`: changes the pen color. See the available pen colors [here](https://www.tcl.tk/man/tcl8.4/TkCmd/colors.htm)
# 1. `pensize(<integer width>)`: changes the pen size to the specified width
# 1. `shape(<turtle string>)`: change the turtle "cursor". See the available shapes [here](https://docs.python.org/3.4/library/turtle.html#turtle.shape)
# 1. Much more!
#
# Here is example turtle code that moves Crush to coordinate (5, 20) and then draws a thick green line 200 pixels (steps) in length:

# %%
# import the turtle graphics module
import turtle

# create a turtle object
crush = turtle.Turtle()
crush.shape("turtle")

# dont draw a line while we move the turtle to the first coordinate
crush.penup()

# move the turtle
crush.setpos(5, 20)

# change pen color and size
crush.pencolor("green")
crush.pensize(10)

# prepare to start drawing
crush.pendown()

# move the turtle
crush.forward(200)

# if running Python as a script: start the GUI (graphical user interface) event loop
turtle.mainloop()

# %% [markdown]
# <img src="https://raw.githubusercontent.com/gsprint23/cpts111/master/labs/figures/turtle_example_line.png" width="500"/>

# %% [markdown]
# ## Task 1
# Write a program to prompt the user to enter two pairs of x, y coordinates. Draw a line that connects these two points (and only these two points) and draw the x, y axes.
#
# Define and call functions that perform the following:
# 1. `draw_axes(my_turtle)`: draws the axes lines using `my_turtle` turtle object
# 1. `draw_line(my_turtle, x1, y1, x2, y2)`: draws the line connecting (`x1`, `y1`) to (`x2`, `y2`)
# 1. `main()`: function that drives your program
#
# Use additional functions where appropriate!
#
# Example: `draw_line(crush, 10, 50, 100, 250)`
# <img src="https://raw.githubusercontent.com/gsprint23/cpts111/master/labs/figures/turtle_line.png" width="500"/>

# %% [markdown]
# ## Task 2
# Write a program to prompt the user to enter the center location of a square and a width of the square.
#
# Define and call functions that perform the following:
# 1. `draw_axes(my_turtle)`: draws the axes lines using `my_turtle` turtle object
# 1. `draw_square(my_turtle, centerx, centery, width)`: draws a square with center and width specified by the user
# 1. `main()`: function that drives your program
#
# Use additional functions where appropriate!
#
# Example: `draw_square(my_turtle, 0, 0, 200)`
# <img src="https://raw.githubusercontent.com/gsprint23/cpts111/master/labs/figures/turtle_square.png" width="500"/>

# %% [markdown]
# ## Task 3
# Write a program that prompts the user to enter the upper left point location of a 5 point start and a length of the star lines. Here is a hint as to how to draw the star:
# ![](https://raw.githubusercontent.com/gsprint23/cpts111/master/labs/figures/pentagram_angles.png)
# (image from [http://i0.wp.com/proofsfromthebook.com/wp-content/uploads/2013/08/pentagram2.png](http://i0.wp.com/proofsfromthebook.com/wp-content/uploads/2013/08/pentagram2.png))
#
# Define and call functions that perform the following:
# 1. `draw_axes(my_turtle)`: draws the axes lines using `my_turtle` turtle object
# 1. `draw_star(my_turtle, startx, starty, line_length)`: draws a star with start position and line length specified by the user
# 1. `main()`: function that drives your program
#
# Use additional functions where appropriate!
#
# Example: `draw_star(my_turtle, 0, 0, 200)`
# <img src="https://raw.githubusercontent.com/gsprint23/cpts111/master/labs/figures/turtle_star.png" width="500"/>
#
# Note: When we learn about loops, we will be able to easily make `n`-pointed stars, where `n` is entered by the user.

# %% [markdown]
# ## Task 4
# Write a program that prompts the user to enter the center location of a 6-arm snowflake, the length of the snowflake arms, and the length of branches at the end of the arms.
#
# Define and call functions that perform the following:
# 1. `draw_axes(my_turtle)`: draws the axes lines using `my_turtle` turtle object
# 1. `draw_snowflake(my_turtle, centerx, centery, arm_length, branch_length)`: draws a 6-arm snowflake with center and lengths specified by the user.
#     1. You may want to define a helper function, such as `draw_arm()` to do this!
# 1. `main()`: function that drives your program
#
# Use additional functions where appropriate!
#
# Example: `draw_snowflake(my_turtle, 0, 0, 150, 75)`
# <img src="https://raw.githubusercontent.com/gsprint23/cpts111/master/labs/figures/turtle_snowflake.png" width="500"/>
#
# Note: When we learn about loops, we will be able to easily make `n`-pointed snowflakes, where `n` is entered by the user.

# %% [markdown]
# ## Task 5
# This task is adapted from problem 3.4 in Schneider, 2014. The problem states the following:
#
# In the word game Mad Libs, people are asked to provide a part of speech, such as a noun, verb, adverb, or adjective. The supplied words are used to fill in the blanks of a preexisting template or replace the same parts of speech in a preexisting sentence. Let's implement code that demonstrates how the game works for a single sentence. Consider this sentence from P. G. Wodehouse:
#
# >Jeeves lugged my purple socks out of the drawer as if he were a vegetarian fishing a caterpillar out of his salad.
#
# Write a program that will do the following:
# * Print the following template:
# > Jeeves [verb] my [adjective] [noun] out of the [noun] as if he were a vegetarian fishing a [noun] out of his salad.
# * Prompt the user for a verb, an adjective, and three nouns.
# * Print the template with the terms in brackets replaced with the words the user provided.
#
# Define and call functions that perform the following:
# 1. Displays instructions to the user
# 1. Prompts the user to enter a part of speech (`part_of_speech` (e.g. "noun") should be a parameter of this function)
# 1. Builds and returns the sentence. Use string concatenation (i.e., the combining of strings with the plus sign) as appropriate.
# 1. Displays the sentence template and final sentence to the user
# 1. `main()`: function that drives your program
#
# Use additional functions where appropriate!

# %% [markdown]
# ## Task 6
# The quadratic equation is given by
# $$ax^2 + bx + c = 0$$
#
# where $a$, $b$, and $c$ are constants and the two values of $x$ that satisfy this equation are the roots or
# solutions to the equation. These values, $x_1$ and $x_2$, are found using the quadratic formula:
# $$x_1 = \frac{−b −\sqrt{b^2 − 4ac}}{2a}$$
# $$x_2 = \frac{−b +\sqrt{b^2 − 4ac}}{2a}$$
#
# Write a program to obtain the solutions to a quadratic equation.
#
# Define and call functions that perform the following:
# 1. `calc_x1_root()`: accepts three arguments: the coefficients $a$, $b$, and $c$. The function returns the values $x_1$ found using the quadratic formula.
# 1. `calc_x2_root()`: accepts three arguments: the coefficients $a$, $b$, and $c$. The function returns the values $x_2$ found using the quadratic formula.
# 1. `main()`: function that drives your program
#
# Use additional functions where appropriate!
#
# You can check your work with [this online quadratic equation solver](http://www.math.com/students/calculators/source/quadratic.htm)

# %% [markdown]
# ## Task 7
# Much of the world uses standard metric units, including speed limits in kilometers (km) per hour. This may lead to issues for American drivers who have no idea how fast or slow 50 km/hr is. In this task you'll provide assistance to American drivers by creating a metric converter so they won't get too excited about a speed limit of 100 km/hr! And while you're at it, you can help Americans get a better feeling for Olympic distances by converting meters to yards. Then they'll be able to appreciate just how speedy some sprinters are.
#
# Write a program that:
# * Prompts users for a distance in meters.
# * Prompts users for a time in minutes.
# * Converts the meters to kilometers.
# * Converts the meters to miles, yards, feet, and inches.
# * Converts the minutes to hours and seconds.
# * Calculates speeds in m/s, yd/s, km/hr, and mi/hr.
# * Displays all the information as demonstrated below.
#
# Define and call functions that perform the following:
# 1. `convert_distance()`
# 1. `convert_time()`
# 1. `calculate_speed()`
# 1. `display_distances()`
# 1. `display_speeds()`
# 1. `main()`: function that drives your program
#
# Use additional functions where appropriate!
#
# Conversion factors are given in the table below.
#
# |meters (m)|to|multiply by|
# |-|-|-|
# |meters|inches|39.37|
# |meters|feet|3.281|
# |meters|yards|1.094|
# |meters|miles|0.0006214|
# |meters|millimeters|1000|
# |meters|centimeters|100|
# |meters|kilometers|0.001|
#
# Example output:
#
# ```
# Please enter the distance [m]: 400.0
# Please enter the time [min]: 0.7197
#
# Original distance: 400.00
# = 0.25 mi
# = 437.60 yd
# = 1312.40 ft
# = 15748.00 in
#
# Your distance and time give speeds of:
# 9.26 m/s, 10.13 yd/s, 33.35 km/hr, and 20.72 mi/hr.
# ```
#
# As an aside, the values above are approximate values for the world record in the 400-m sprint held
# by Michael Johnson. Is this the fastest speed humans have run? Hint: Usain Bolt

# %% [markdown]
# ## Task 8
# This task is adapted from chapter 3 (problem 13) Hanly & Koffman. The problem states the following:
#
# After studying the population growth of Gotham City in the last decade of the 20th century, we have modeled Gotham’s population function as
#
# $$P(t) = 52.966 + 2.184t$$
#
# where $t$ is years after 1990, and $P$ is population in thousands. Thus, $P(0)$ represents the population in 1990, which was 52.966 thousand people.
#
# Write a program that predicts Gotham's population in the year provided from the user.
#
#
# Define and call functions that perform the following:
# 1. Prompts the user for the year
# 1. Computes the predicted population
# 1. Displays the results to the user
# 1. `main()`: function that drives your program
#
# Use additional functions where appropriate!
#
# Example output:
#
# ```
# Please enter a year after 1990: 2015
# Predicted Gotham City population for 2015 (in thousands): 107.566
# ```

# %% [markdown]
# ## Task 9
# This task is adapted from chapter 3 (problem 3-1) in Downey. The problem states the following:
#
# Write a program that prompts the user to enter a string. Your program should display the string with enough leading spaces so that the last letter of the string is in column 70 of the display.
#
# Define and call functions that perform the following:
# 1. Prompts the user for the string
# 1. `right_justify()`: displays the user's string right justified
# 1. `main()`: function that drives your program
#
# Use additional functions where appropriate!
#
# Hint: Use string concatenation (`+`) and string repetition (`*`). Do not use loops to do this! Also, Python provides a built-in function called `len()` that returns the length of a string (number of characters). Here is an example:

# %%
my_str = "pullman"
print(len(my_str))
padding = 10 * " "
print(padding + my_str)
# Out:
# 7
#           pullman

# %% [markdown]
# ## Task 10
# Complete this task after completing Task 9.
#
# This task is adapted from chapter 3 (problem 3-3) in Downey. The problem states the following:
#
# Write a program that prompts the user for a box size and number of boxes. The program should display a box like the following (size 4):
#
# ```
# +- - - - +
# |        |
# |        |
# |        |
# |        |
# +- - - - +
# ```
#
# Do not use loops to do this!
#
# The program should display as many boxes as the user specifies, one per line. Do not use loops to do this either!
#
# Define and call functions that perform the following:
# 1. Prompts the user for the box size
# 1. Prompts the user for the number of boxes
# 1. `generate_box()`: builds a string representing a box of size specified by the user
# 1. `generate_boxes()`: builds a string representing all boxes (number of boxes specified by user)
# 1. `main()`: function that drives your program
#
# Use additional functions where appropriate!
#
# Example output:
#
# ```
# Please enter the size of a box: 6
# Please enter the number of boxes: 3
# +- - - - - - +
# |            |
# |            |
# |            |
# |            |
# |            |
# |            |
# +- - - - - - +
# +- - - - - - +
# |            |
# |            |
# |            |
# |            |
# |            |
# |            |
# +- - - - - - +
# +- - - - - - +
# |            |
# |            |
# |            |
# |            |
# |            |
# |            |
# +- - - - - - +
# ```

# %% [markdown]
# ## Challenge Task
# The `turtle` module contains a function called [`onkey(<function>, <key string>)`](https://docs.python.org/3.5/library/turtle.html#turtle.onkey) that *binds* a function to a keystroke. For example:
#
# ```
# import turtle
# turtle.onkey(forward, "Up")
# ```
#
# This line of code binds a function named `forward()` to the "Up" key on your keyboard. This means that if the user presses the "Up" key, the function `forward()` will be called behind the scenes by Python.
#
# Write a program to allow the user to move the turtle on the canvas by using the "Up", "Down", "Left", and "Right" arrow keys.
#
# Define and call functions that perform the following:
# 1. `forward()`: moves the turtle forward 10 steps when the user presses the "Up" key
# 1. `backward()`: moves the turtle backward 10 steps when the user presses the "Down" key
# 1. `ccw()`: moves the turtle 45 degrees counter clockwise when the user presses the "Left" key
# 1. `cw()`: moves the turtle 45 degrees clockwise when the user presses the "Right" key
# 1. `main()`: function that drives your program
#
# Also, try adding this additional functionality (see the `turtle` module [documentation](https://docs.python.org/3.5/library/turtle.html) for help on how to do this):
# 1. `home()`: moves the turtle back to the origin when the user presses the "h" key
# 1. `clear()`: clears the canvas when the user presses the "c" key
# 1. `quit_program()`: closes the turtle window and exits the program when the user presses the "q" key
# 1. Others? Have fun with it!
#
# Use additional functions where appropriate!
#
# Example output:
#
# ```
# Forward: 10
# Forward: 10
# Forward: 10
# Forward: 10
# Forward: 10
# Forward: 10
# Forward: 10
# Forward: 10
# Forward: 10
# Forward: 10
# Counter clockwise: 45
# Counter clockwise: 45
# Counter clockwise: 45
# Forward: 10
# Forward: 10
# Forward: 10
# Forward: 10
# Forward: 10
# Forward: 10
# Forward: 10
# Counter clockwise: 45
# Counter clockwise: 45
# Forward: 10
# Forward: 10
# Forward: 10
# Forward: 10
# Forward: 10
# Forward: 10
# ```
# <img src="https://raw.githubusercontent.com/gsprint23/cpts111/master/labs/figures/turtle_triangle.png" width="500"/>
#
# Note: To do this task, we will declare our turtle object (i.e. `my_turtle`) as a global variable, before the definitions of the functions that we are binding to keys. This is because we cannot specify the arguments into our binded functions. In general, we try to avoid using global variables; however, we have not learned enough of Python (yet) to do this in a more elegant way, stay tuned!
